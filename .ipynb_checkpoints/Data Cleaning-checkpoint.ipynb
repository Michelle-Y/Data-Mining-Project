# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pylab as plt
from docx import *
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8ed0640d34c0> in <module>()
#       3 import sys
#       4 import matplotlib.pylab as plt
# ----> 5 from docx import *
#       6 get_ipython().magic('matplotlib inline')
#
# ModuleNotFoundError: No module named 'docx'

# %%
file1= pd.read_csv("C:/Users/zzh/Dropbox/CSCI4502/Project/CSV/Book2.csv", names=Title)

# %%
Title=('EmotionLevel','TwitterID','PostTime','IsQuery','Username','Content')

# %%
file1.head(100)
# Out:
#     EmotionLevel   TwitterID                      PostTime   IsQuery  \
# 0              0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1              0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2              0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3              0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4              0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 5              0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 6              0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7              0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 8              0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 9              0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
# 10             0  1467812416  Mon Apr 06 22:20:16 PDT 2009  NO_QUERY
# 11             0  1467812579  Mon Apr 06 22:20:17 PDT 2009  NO_QUERY
# 12             0  1467812723  Mon Apr 06 22:20:19 PDT 2009  NO_QUERY
# ...

# %%
file1=file1.drop('TwitterID',1)

# %%
file1=file1.drop('IsQuery',1)

# %%
file1=file1.drop('Username',1)

# %%
file1.head(100)
# Out:
#     EmotionLevel                      PostTime  \
# 0              0  Mon Apr 06 22:19:45 PDT 2009
# 1              0  Mon Apr 06 22:19:49 PDT 2009
# 2              0  Mon Apr 06 22:19:53 PDT 2009
# 3              0  Mon Apr 06 22:19:57 PDT 2009
# 4              0  Mon Apr 06 22:19:57 PDT 2009
# 5              0  Mon Apr 06 22:20:00 PDT 2009
# 6              0  Mon Apr 06 22:20:03 PDT 2009
# 7              0  Mon Apr 06 22:20:03 PDT 2009
# 8              0  Mon Apr 06 22:20:05 PDT 2009
# 9              0  Mon Apr 06 22:20:09 PDT 2009
# 10             0  Mon Apr 06 22:20:16 PDT 2009
# 11             0  Mon Apr 06 22:20:17 PDT 2009
# 12             0  Mon Apr 06 22:20:19 PDT 2009
# 13             0  Mon Apr 06 22:20:19 PDT 2009
# 14             0  Mon Apr 06 22:20:20 PDT 2009
# 15             0  Mon Apr 06 22:20:20 PDT 2009
# 16             0  Mon Apr 06 22:20:22 PDT 2009
# 17             0  Mon Apr 06 22:20:25 PDT 2009
# 18             0  Mon Apr 06 22:20:31 PDT 2009
# ...

# %%
file1['Content'][20]
# Out:
# "@alydesigns i was out most of the day so didn't get much done "

# %%
count=file1['EmotionLevel'].value_counts();

# %%
print(count)
# Out:
# 0    800000
# 4    248576
# Name: EmotionLevel, dtype: int64

# %%
filepos= pd.read_csv("C:/Users/zzh/Desktop/PositiveText.txt", sep=" ", names=Title1
)

# %%
Title1=('h')

# %%
filepos.head
# Out:
# <bound method NDFrame.head of                     h
# 0              abound
# 1             abounds
# 2           abundance
# 3            abundant
# 4          accessable
# 5          accessible
# 6             acclaim
# 7           acclaimed
# 8         acclamation
# 9            accolade
# 10          accolades
# 11      accommodative
# 12       accomodative
# 13         accomplish
# 14       accomplished
# 15     accomplishment
# 16    accomplishments
# 17           accurate
# 18         accurately
# 19         achievable
# 20        achievement
# 21       achievements
# 22         achievible
# 23             acumen
# 24          adaptable
# 25           adaptive
# 26           adequate
# 27         adjustable
# 28          admirable
# 29          admirably
# ...               ...
# 1975            witty
# 1976              won
# 1977           wonder
# 1978        wonderful
# 1979      wonderfully
# 1980        wonderous
# 1981      wonderously
# 1982          wonders
# ...

# %%
sum = 0
for j in file1['Content']:
    for i in filepos.h:
        if i in j:
            sum+=1
print(sum)
# Out:
# 837799

# %%
filepos.h[12]
# Out:
# 'accomodative'

# %%
for line in filepos:
    list.append(line)

# %%
Title2=('h')
fileneg= pd.read_csv("C:/Users/zzh/Desktop/negativeText.txt", sep=" ",names=Title2)

# %%
fileneg.head
# Out:
# <bound method NDFrame.head of                   h
# 0                2-
# 1             faced
# 2           2-faces
# 3          abnormal
# 4           abolish
# 5        abominable
# 6        abominably
# 7         abominate
# 8       abomination
# 9             abort
# 10          aborted
# 11           aborts
# 12           abrade
# 13         abrasive
# 14           abrupt
# 15         abruptly
# 16          abscond
# 17          absence
# 18    absent-minded
# 19         absentee
# 20           absurd
# 21        absurdity
# 22         absurdly
# 23       absurdness
# 24            abuse
# 25           abused
# 26           abuses
# 27          abusive
# 28          abysmal
# 29        abysmally
# ...             ...
# 4754          wrath
# 4755          wreak
# 4756        wreaked
# 4757         wreaks
# 4758          wreck
# 4759          wrest
# 4760        wrestle
# 4761         wretch
# 4762       wretched
# 4763     wretchedly
# 4764   wretchedness
# 4765        wrinkle
# ...

# %%
sum = 0
s=0
for j in file1['Content']:
    for i in fileneg.h:
        if i in j:
            sum+=1
print(sum)
# Out:
# 903898

# %%
p=[]
n=[]

ind=-1
for tweets in file1['Content'][50000:70000]:
    ind+=1
    possum =0
    negsum =0
    for pos,neg in zip(filepos.h,fileneg.h):
        if neg in tweets:
            negsum+=1
        if pos in tweets:
            possum+=1
    
    
    if file1['EmotionLevel'][ind]==0:
        n.append(negsum)
    else:
        p.append(possum)
        
    
    if ind % 2000 ==0:
        print("%d %d %d" %(file1['EmotionLevel'][ind],possum,negsum))

print(sum(p)/float(len(p)))
print(sum(n)/float(len(n)))
# Out:
# 0 1 2
# 0 0 1
# 0 1 2
# 0 3 0
# 0 0 2
# 0 2 0
# 0 0 1
# 0 2 0
# 0 0 0
# 0 3 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-0c4087b4b622> in <module>()
#      23         print("%d %d %d" %(file1['EmotionLevel'][ind],possum,negsum))
#      24
# ---> 25 print(sum(p)/float(len(p)))
#      26 print(sum(n)/float(len(n)))
#
# TypeError: 'int' object is not callable

# %%
# Out:
# 1 11
# 2 22
# 3 33
# 4 44
# 5 55
# 6 66
# 7 77
